# %% [markdown]
# ## Question 5. Quality Checks
#
# You want to ensure the pickup_datetime column in your trips table never has NULL values. Which quality check should you add to your asset definition?
#
# - name: unique
# - name: not_null
# - name: positive
# - name: accepted_values, value: [not_null]

# %% [markdown]
# Answer - name: not_null
#
# Explanation -
#
# We want to ensure that the pickup_datetime column never contains NULL values.
#
# The correct quality check for this requirement is: not_null
#
# This check validates that every row in the column has a value and none are NULL.
