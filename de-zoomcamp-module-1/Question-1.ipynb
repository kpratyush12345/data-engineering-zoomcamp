# %% [markdown]
# # Question 1: Run python:3.13 & check pip version
#
# ## Step 1: Pull and run the container with bash entrypoint
#
# Run this:

# %%
docker run -it --entrypoint bash python:3.13

# %% [markdown]
# You’ll enter the container like: root@xxxxx:/#
#
# ## Step 2: Check pip version
#
# Inside the container run:

# %%
pip --version

# %% [markdown]
# ![Question 1 Image](images/question1.png)

# %% [markdown]
# Answer : What's the version of pip in the image?
#
# 25.3
