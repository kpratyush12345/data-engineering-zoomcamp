# %% [markdown]
# # Question 7. Terraform Workflow
#
# Which of the following sequences, respectively, describes the workflow for:
#
# - Downloading the provider plugins and setting up backend,
# - Generating proposed changes and auto-executing the plan
# - Remove all resources managed by terraform`

# %% [markdown]
# Correct answer:
# terraform init, terraform apply -auto-approve, terraform destroy
#
# Why (matches each part of the workflow):
# - Downloading provider plugins + backend setup → terraform init
# - Generate plan + auto-execute → terraform apply -auto-approve
# (this creates the plan internally and applies it automatically)
# - Remove all Terraform-managed resources → terraform destroy
