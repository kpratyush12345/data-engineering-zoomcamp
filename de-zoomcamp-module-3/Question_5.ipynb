# %% [markdown]
# ## Question 5. Partitioning and clustering
#
# What is the best strategy to make an optimized table in Big Query if your query will always filter based on tpep_dropoff_datetime and order the results by VendorID (Create a new table with this strategy)
#
# - Partition by tpep_dropoff_datetime and Cluster on VendorID
# - Cluster on by tpep_dropoff_datetime and Cluster on VendorID
# - Cluster on tpep_dropoff_datetime Partition by VendorID
# - Partition by tpep_dropoff_datetime and Partition by VendorID

# %% [markdown]
# Answer: Partition by tpep_dropoff_datetime and cluster on VendorID
#
# Why this is the best strategy
# Question says:
# - your queries will always filter on tpep_dropoff_datetime
# - and order / group by VendorID
#
# So in BigQuery:
# - Partitioning should be done on the column used in the WHERE filter
# - Clustering should be done on the column used for sorting / grouping
#
# That maps perfectly to:
# - Partition → tpep_dropoff_datetime
# - Cluster → VendorID
#
# This is how you would create the optimized table

# %%
CREATE OR REPLACE TABLE `zoomcamp_hw3.yellow_tripdata_2024_optimized`
PARTITION BY DATE(tpep_dropoff_datetime)
CLUSTER BY VendorID
AS
SELECT *
FROM `zoomcamp_hw3.yellow_tripdata_2024`;

# %% [markdown]
# ![Question 5](./images/question5.png)
