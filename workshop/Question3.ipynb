# %% [markdown]
# ## Question 3: What is the total amount of money generated in tips?
#
# - $4,063.41
# - $6,063.41
# - $8,063.41
# - $10,063.41

# %% [markdown]
# Answer: $6,063.41
#
# Created a new file question_2.py and paste the below code

# %%
import duckdb

con = duckdb.connect("taxi_pipeline.duckdb")

print(
    con.execute("""
        SELECT ROUND(SUM(tip_amt), 2) AS total_tips
        FROM taxi_data.yellow_taxi_trips
    """).fetchdf()
)

# %% [markdown]
# ![Question 3](./images/question3.png)

# %% [markdown]
# ## Using Marimo -
#
# From the Marimo Dashboard add a new cell and paste this -

# %%
total_tips = trips.tip_amt.sum()

total_tips.execute()

# %% [markdown]
# Run the cell and the output will look something like this
#
# ![Marimo Question 3](./images/question3_marimo.png)
